# %%
import pandas as pd
import numpy as np

# %%
SA_stopin = pd.read_csv('SA_stopin.csv')
df_transport = pd.read_csv('df_transport.csv')
LookUp_SA_LGD = pd.read_csv('LookUp_SA_LGD.csv')

# %%
SA_stopin.columns = ['Index', 'SA2011','stop_in']

# %%
SA_stopin.head(5)
# Out:
#    Index     SA2011  stop_in
# 0      0  N00000001        0
# 1      1  N00000001        0
# 2      2  N00000001        0
# 3      3  N00000001        0
# 4      4  N00000002        1

# %%
df_transport.head(5)
# Out:
#      LGD2014   LGD1992NAME           Platform Name StationType  X-Coordinate  \
# 0  N09000001        ANTRIM      Antrim Bus Station    Bus Only      315242.0
# 1  N09000002        ARMAGH      Armagh Bus Station    Bus Only      287568.0
# 2  N09000001  NEWTOWNABBEY  Ballyclare Bus Station    Bus Only      328968.0
# 3  N09000008     BALLYMENA   Ballymena Bus Station    Bus Only      309995.0
# 4  N09000002     BANBRIDGE   Banbridge Bus Station    Bus Only      312667.0
#
#    Y-Coordinate
# 0      387025.0
# 1      345496.0
# 2      390775.0
# 3      403130.0
# 4      345925.0

# %%
df_transport['LGD2014'][0]
# Out:
# 'N09000001'

# %%
SA_stopin['SA2011'][0]
# Out:
# 'N00000001'

# %%
LookUp_SA_LGD.head(5)
# Out:
#       SA2011    LGD2014              LGD2014NAME
# 0  N00000001  N09000001  Antrim and Newtownabbey
# 1  N00000002  N09000001  Antrim and Newtownabbey
# 2  N00000003  N09000001  Antrim and Newtownabbey
# 3  N00000004  N09000001  Antrim and Newtownabbey
# 4  N00000005  N09000001  Antrim and Newtownabbey

# %%
temp_df = pd.merge(df_transport,LookUp_SA_LGD,on='LGD2014')

# %%
temp_df.head(5)
# Out:
#      LGD2014 LGD1992NAME       Platform Name StationType  X-Coordinate  \
# 0  N09000001      ANTRIM  Antrim Bus Station    Bus Only      315242.0
# 1  N09000001      ANTRIM  Antrim Bus Station    Bus Only      315242.0
# 2  N09000001      ANTRIM  Antrim Bus Station    Bus Only      315242.0
# 3  N09000001      ANTRIM  Antrim Bus Station    Bus Only      315242.0
# 4  N09000001      ANTRIM  Antrim Bus Station    Bus Only      315242.0
#
#    Y-Coordinate     SA2011              LGD2014NAME
# 0      387025.0  N00000001  Antrim and Newtownabbey
# 1      387025.0  N00000002  Antrim and Newtownabbey
# 2      387025.0  N00000003  Antrim and Newtownabbey
# 3      387025.0  N00000004  Antrim and Newtownabbey
# 4      387025.0  N00000005  Antrim and Newtownabbey

# %%
new_df = pd.merge(temp_df,SA_stopin,on='SA2011')

# %%
new_df.tail(5)
# Out:
#          LGD2014 LGD1992NAME Platform Name    StationType  X-Coordinate  \
# 55855  N09000005       DERRY       Derry 1  Train Station     243994.36
# 55856  N09000005       DERRY       Derry 2  Train Station     243998.72
# 55857  N09000005       DERRY       Derry 2  Train Station     243998.72
# 55858  N09000005       DERRY       Derry 2  Train Station     243998.72
# 55859  N09000005       DERRY       Derry 2  Train Station     243998.72
#
#        Y-Coordinate     SA2011         LGD2014NAME  Index  stop_in
# 55855     416375.52  N00004537  Derry and Strabane  18147        1
# 55856     416370.82  N00004537  Derry and Strabane  18144        1
# 55857     416370.82  N00004537  Derry and Strabane  18145        1
# 55858     416370.82  N00004537  Derry and Strabane  18146        1
# 55859     416370.82  N00004537  Derry and Strabane  18147        1

# %%
new_df.plot(x="LGD2014", y=["stop_in"], kind="bar", figsize=(9, 8))

# %%
import matplotlib as plt

# %%
import seaborn as sns
sns.set(style="darkgrid")
#titanic = sns.load_dataset("titanic")

#fig, ax = plt.subplots(figsize = (9, 5))
ax = sns.countplot(x="stop_in", data=SA_stopin)
#ax.set_axis_labels('No Public transport stop', 'Public transport Available')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-09d87da8ab90> in <module>
#       5 #fig, ax = plt.subplots(figsize = (9, 5))
#       6 ax = sns.countplot(x="stop_in", data=SA_stopin)
# ----> 7 ax.set_axis_labels('No Public transport stop', 'Public transport Available')
#       8
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_axis_labels'
