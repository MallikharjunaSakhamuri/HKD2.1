# %%
import pandas as pd
import numpy as np

# %%
Dataset_SORN = pd.read_csv('Dataset_SORN.csv')
Public_walks = pd.read_csv('Journeys_made.csv')

# %%
Public_walks.head(5)
# Out:
#                                 LGD2014 LGD2014 Code  2017-2019  2016-2018  \
# 0               Antrim and Newtownabbey    N09000001         25         27
# 1  Armagh City, Banbridge and Craigavon    N09000002         15         15
# 2                               Belfast    N09000003         44         42
# 3              Causeway Coast and Glens    N09000004         25         23
# 4               Derry City and Strabane    N09000005         29         33
#
#    2015-2017  2014-2016  2013-2015  2012-2014
# 0         22         19         16         17
# 1         19         21         22         21
# 2         41         35         36         35
# 3         22         21         22         24
# 4         33         32         30         29

# %%
Dataset_SORN.head(5)
# Out:
#                           AA  Licensed Vehicles  Unnamed: 2  SORN Vehicles
# 0   N06000001 - Belfast East              56270         NaN           4915
# 1  N06000002 - Belfast North              46723         NaN           5339
# 2  N06000003 - Belfast South              60099         NaN           5145
# 3   N06000004 - Belfast West              35790         NaN           4337
# 4    N06000005 - East Antrim              59169         NaN          10200

# %%
Dataset_SORN[['LGD2014 Code', 'LGD2014']] = Dataset_SORN['AA'].str.split(' ', n=1, expand=True)

# %%
Dataset_SORN.head(5)
# Out:
#                           AA  Licensed Vehicles  Unnamed: 2  SORN Vehicles  \
# 0   N06000001 - Belfast East              56270         NaN           4915
# 1  N06000002 - Belfast North              46723         NaN           5339
# 2  N06000003 - Belfast South              60099         NaN           5145
# 3   N06000004 - Belfast West              35790         NaN           4337
# 4    N06000005 - East Antrim              59169         NaN          10200
#
#   LGD2014 Code          LGD2014
# 0    N06000001   - Belfast East
# 1    N06000002  - Belfast North
# 2    N06000003  - Belfast South
# 3    N06000004   - Belfast West
# 4    N06000005    - East Antrim

# %%
#Dataset_SORN = pd.merge(Dataset_SORN,Public_walks,on='LGD2014')

# %%
Dataset_SORN["Licensed Vehicles"] = pd.to_numeric(Dataset_SORN["Licensed Vehicles"])
Dataset_SORN["SORN Vehicles"] = pd.to_numeric(Dataset_SORN["SORN Vehicles"])

# %%
Dataset_SORN.plot(x="LGD2014", y=["Licensed Vehicles", "SORN Vehicles"], kind="bar", figsize=(9, 8))

# %%
Public_walks.plot(x="LGD2014", y=["2017-2019"], kind="bar", figsize=(9, 8))
